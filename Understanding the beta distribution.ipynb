# %%
from scipy.stats import beta
from scipy.special import btdtri
import numpy as np
import matplotlib
# %matplotlib inline
matplotlib.style.use('ggplot')
from pylab import rcParams
rcParams['figure.figsize'] = 12, 6

# %%
# http://varianceexplained.org/statistics/beta_distribution_and_baseball/
a =  81
b = 219
x = np.arange (0.01, 1, 0.01)
y = beta.pdf(x,a,b)
plt.plot(x,y);

# %%
a =  2
b = 2
x = np.linspace(0, 1.0, 100)
y1 = beta.pdf(x, 2.75, 2.75)
y2 = beta.pdf(x, 3.25, 3.25)
y3 = beta.pdf(x, 3, 3)
# plt.plot(x, y1, "-", x, y2, "--", x, y3, ".")
plt.plot(x, y1, x, y2, x, y3);

# %%
a =  2
b = 2
x = np.linspace(0, 1.0, 100)
y1 = beta.pdf(x, 2.75, 2.75)
y2 = beta.pdf(x, 3.25, 3.25)
y3 = beta.pdf(x, 3, 3)
# plt.plot(x, y1, "-", x, y2, "--", x, y3, ".")
plt.plot(x, y1, x, y2, x, y3);

# %%
s1 = beta.pdf(x,81,219)
s2 = beta.pdf(x,81+1,219)
s3 = beta.pdf(x,162,438)
plt.plot(x,s1,'-',x,s2,'--',x,s3);

# %%
# fig = plt.figure(figsize=(12, 6))
s4 = beta.pdf(x, 81+100, 219+200)
plt.plot(x,s1,x,s3,x,s4);

# %%
x = np.linspace(0, 1, 100)
y = beta.pdf(x,1,1)
plt.plot(x,y);

# %%
y = beta.pdf(x,2,1)
plt.plot(x,y);

# %%
y = beta.pdf(x,3,1)
plt.plot(x,y);

# %%
y = beta.pdf(x,3,2)
plt.plot(x,y);

# %%
y = beta.pdf(x,10,4)
plt.plot(x,y);

# %%
y = beta.pdf(x,140,110)
plt.plot(x,y);

# %%
print((x*y).mean())
print(btdtri(140, 110, 0.1))
print(btdtri(140, 110, 0.9))
# Out:
# 0.552115384615
# 0.519690611046
# 0.600102643711

# %%
y = beta.pdf(x,5,5)
plt.plot(x,y);

# %%
y = beta.pdf(x,140+5,110+5)
plt.plot(x,y);

# %%
print((x*y).mean())
print(btdtri(140, 110, 0.1))
print(btdtri(140, 110, 0.9))
# Out:
# 0.552115384615
# 0.519690611046
# 0.600102643711

# %%
y = beta.pdf(x,140+1,110+1)
plt.plot(x,y);

# %%
print((x*y).mean())
print(btdtri(140, 110, 0.1))
print(btdtri(140, 110, 0.9))
# Out:
# 0.553928571429
# 0.519690611046
# 0.600102643711

# %%
# x = np.linspace(0, 1.0, 100)
x = np.arange (0, 0.18, 0.0001)
s1 = beta.pdf(x,5,200)
s2 = beta.pdf(x,2,80)
s3 = beta.pdf(x,1,41)
plt.plot(x,s1,x,s2,x,s3);

# %%
# https://www.countbayesie.com/blog/2015/4/4/parameter-estimation-adding-bayesian-priors
x = np.arange (0, 1, 0.0001)
s1 = beta.pdf(x,2,3)
s2 = beta.pdf(x,2+1,3+41)
plt.plot(x,s1, label='s1')
plt.plot(x,s2, label='s2')
plt.legend();
